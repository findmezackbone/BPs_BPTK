# %%
import numpy as np
from tqdm import tqdm 
import torch
import numpy as np
import random
import itertools
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
import numpy as np
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
import sys
sys.path.append("D:\\1st\\BPs_BPTK\\Python") 
from BPS_init_function_MultiParas import BPS_BPTK_MultiParas
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False # 用来正常显示负号
from sklearn.metrics import r2_score
import scipy.stats as stats
import os
os.chdir('d:\\1st\\BPs_BPTK')

input =  np.load("Python\\optim\\Time_DualNN14\\database\\input_add2.npy")
label =  np.load("Python\\optim\\Time_DualNN14\\database\\label_add2.npy")

# %%
num = 120000
id = 0
time = np.arange(0,75,0.005)
para = np.reshape(label[num,:], (1,-1))


_,urine,urineg  =  BPS_BPTK_MultiParas(t = time,volunteer_ID =id, paras = para ,mode = '63')

print(para)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  3.79it/s]
# [[10.00229576  6.90679689  5.18127604]]

# %%
plt.scatter(input[num,14:28]/200,input[num,0:14],label = '14个采样点', c='red')
plt.plot(time,urine[0,:]+urineg[0,:],label = '尿液BPS类含量曲线')
plt.xlabel('时间(h)')
plt.ylabel('尿液内BPS类含量(mmol)')
plt.legend()
plt.show()

# %%
plt.scatter(input[num,14:28]/200,input[num,0:14],label = '14个采样点', c='red')
plt.plot(time,urine[0,:]+urineg[0,:],label = '尿液BPS类含量曲线')
plt.xlabel('时间(h)')
plt.ylabel('尿液内BPS类含量(mmol)')
plt.legend()
plt.show()

# %%
print(para)
# Out:
# [[25.63171889  6.84459771  2.79277795]]
